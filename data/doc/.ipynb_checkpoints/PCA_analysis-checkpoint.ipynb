# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
pca = pickle.load(open("../model/pca.m", 'rb'))
# Out:
# /Users/ymon0003/opt/anaconda3/envs/astroconda/lib/python3.6/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator PCA from version 0.20.3 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
for p in pca.components_:
    plt.imshow(p.reshape((21,21)), cmap='gray')
    plt.colorbar()
    plt.show()
